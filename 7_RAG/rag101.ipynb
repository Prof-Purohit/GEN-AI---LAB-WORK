# %%
# Install required libraries
! pip install langchain pdf2image pypdf chromadb llama-cpp-python ctransformers sentence-transformers -q

# %%
# Let's download related gguf model
! huggingface-cli download TheBloke/Mistral-7B-Instruct-v0.2-GGUF mistral-7b-instruct-v0.2.Q4_K_M.gguf --local-dir . --local-dir-use-symlinks False
# Out:
# Consider using `hf_transfer` for faster downloads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# downloading https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.2-GGUF/resolve/main/mistral-7b-instruct-v0.2.Q4_K_M.gguf to /root/.cache/huggingface/hub/tmpxaf7ai5y
# mistral-7b-instruct-v0.2.Q4_K_M.gguf: 100% 4.37G/4.37G [00:35<00:00, 125MB/s]
# ./mistral-7b-instruct-v0.2.Q4_K_M.gguf

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter ,RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.prompts import PromptTemplate
from langchain_community.document_loaders import PyPDFLoader
from ctransformers import AutoModelForCausalLM

# %%
mistral = "/content/mistral-7b-instruct-v0.2.Q4_K_M.gguf"

# %%
def build_llm(name):
  llm = AutoModelForCausalLM.from_pretrained(name ,temperature=0.2,repetition_penalty=1.1,gpu_layers=50,model_type="llama2",max_new_tokens = 1000,context_length = 6000)
  return llm

# %%
llm_mistral = build_llm(mistral)

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
path_name = 'pdf1.pdf'
loader = PyPDFLoader(path_name)
documents = loader.load()

# %%
# split it into chunks
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=100)
docs = text_splitter.split_documents(documents)

# %%
# !rm -rf chroma_db

# %%
# save to disk
db2 = Chroma.from_documents(docs, embeddings, persist_directory="./new_chroma_db")

# %%
# loading chroma data from disk
db = Chroma(persist_directory="./new_chroma_db", embedding_function=embeddings)

# %%
# Querying data from ChromaDB
query = "Who is the author of the book and what is his connection to the character Mark?"
docs = db2.similarity_search(query,k=7)
docs
# Out:
# [Document(page_content="Donna sees Mark on the boat to Spain. She likes him \nand he likes her. Then Mark sees Donna dancing with \nhis brother, Dave ... Is Donna in love with Mark? \nWhy is Dave dancing with her? \nPenguin Readers are simplified texts designed in association with \nLongman, the world famous educational publisher, to provide a step-by-\nstep approach to the joys of reading for pleasure. The series includes \noriginal stories, contemporary titles based on today's best-selling media \nhits, and easily accessible versions of the literary classics published by \nPenguin around the world. Each book has an introduction and extensive \nactivity material. They are published at seven levels from Easystarts (200 \nwords) to Advanced (3000 words). \nSeries Editors: Andy Hopkins and Jocelyn Potter \n6 Advanced (3000 words) \n5 Upper Intermediate (2300 words) \n4 Intermediate (1700 words) \n3 Pre-lntermediate (1200 words) \n2 Elementary (600 words) \nI Beginner (300 words) \nEasystarts (200 words) Contemporary \nClassics \nOriginals \nBritish English \nAmerican English \nCover illustration Richard Jones \nLONGMAN \nPublished and distributed by \nAddison Wesley Longman", metadata={'page': 33, 'source': '/content/pdf1.pdf'}),
#  Document(page_content="Donna sees Mark on the boat to Spain. She likes him \nand he likes her. Then Mark sees Donna dancing with \nhis brother, Dave ... Is Donna in love with Mark? \nWhy is Dave dancing with her? \nPenguin Readers are simplified texts designed in association with \nLongman, the world famous educational publisher, to provide a step-by-\nstep approach to the joys of reading for pleasure. The series includes \noriginal stories, contemporary titles based on today's best-selling media \nhits, and easily accessible versions of the literary classics published by \nPenguin around the world. Each book has an introduction and extensive \nactivity material. They are published at seven levels from Easystarts (200 \nwords) to Advanced (3000 words). \nSeries Editors: Andy Hopkins and Jocelyn Potter \n6 Advanced (3000 words) \n5 Upper Intermediate (2300 words) \n4 Intermediate (1700 words) \n3 Pre-lntermediate (1200 words) \n2 Elementary (600 words) \nI Beginner (300 words) \nEasystarts (200 words) Contemporary \nClassics \nOriginals \nBritish English \nAmerican English \nCover illustration Richard Jones \nLONGMAN \nPublished and distributed by \nAddison Wesley Longman", metadata={'page': 33, 'source': '/content/pdf1.pdf'}),
#  Document(page_content="Mark didn't want to go. He didn't want to eat or \ndance or talk and laugh. He wanted to sit quietly and \nthink about the good-looking girl on the boat. Where \nwas she now? But Dave and Harry and Nick and Sue \nall wanted him to go . . . \nLater that evening he walked into the square at \nComillas with his friends. They found a table at one of \nthe cafes and they all sat down. \n28", metadata={'page': 28, 'source': '/content/pdf1.pdf'}),
#  Document(page_content="Mark didn't want to go. He didn't want to eat or \ndance or talk and laugh. He wanted to sit quietly and \nthink about the good-looking girl on the boat. Where \nwas she now? But Dave and Harry and Nick and Sue \nall wanted him to go . . . \nLater that evening he walked into the square at \nComillas with his friends. They found a table at one of \nthe cafes and they all sat down. \n28", metadata={'page': 28, 'source': '/content/pdf1.pdf'}),
#  Document(page_content='Girl Meets Boy \nDEREK STRANGE \nLevel 1 \nSeries Editors: Andy Hopkins and Jocelyn Potter', metadata={'page': 3, 'source': '/content/pdf1.pdf'}),
#  Document(page_content='Girl Meets Boy \nDEREK STRANGE \nLevel 1 \nSeries Editors: Andy Hopkins and Jocelyn Potter', metadata={'page': 3, 'source': '/content/pdf1.pdf'}),
#  Document(page_content="Exercises \nVocabulary Work \nLook again at the 'Dictionary Words' in this story. Are they nouns \nor verbs or adjectives? Write the words and write N (for noun), V \n(for verb) or A (for adjective), e.g. story (N), bird (N). \nThen write short sentences with the new words. \nComprehension \nAnswer the questions. \nDonna's story \n1 (page 5) When was the first day of Donna's holiday? \n2 (page 6) Where was she when she first saw Mark? \n3 (page 9) How long were Donna and Mark on the boat together? \n4 (page 12) Who was on the dance-floor with Donna when she \nsaw Mark at the door of the disco? \n5 (page 15) At what time did the boat arrive in Santander? \nMark's story \n6 (page 16) What is Mark's name for his Spanish teacher? \n7 page 16) How long was Mark's holiday in Spain? \n8 (page 22) What did Mark do when he got up early in the morning? \nThe town's story \n9 (page 24) Where is Comillas? \n10 (page 24) What do people do in the square in Comillas in \nthe evenings in July and August? \n11 (page 26) Who wanted Mark to go to the dance in Comillas? \n12 (page 30) What was Dave's plan for Mark? \nDiscussion \n1 Are you shy? When and why (or why not)? \nDo you like dancing and discos? Why or why not? \n31", metadata={'page': 31, 'source': '/content/pdf1.pdf'})]

# %%
# Making a string of related verses.
verses = ""

for doc in docs:
    verses += doc.page_content + "\n"

# %%
verses
# Out:
# "Donna sees Mark on the boat to Spain. She likes him \nand he likes her. Then Mark sees Donna dancing with \nhis brother, Dave ... Is Donna in love with Mark? \nWhy is Dave dancing with her? \nPenguin Readers are simplified texts designed in association with \nLongman, the world famous educational publisher, to provide a step-by-\nstep approach to the joys of reading for pleasure. The series includes \noriginal stories, contemporary titles based on today's best-selling media \nhits, and easily accessible versions of the literary classics published by \nPenguin around the world. Each book has an introduction and extensive \nactivity material. They are published at seven levels from Easystarts (200 \nwords) to Advanced (3000 words). \nSeries Editors: Andy Hopkins and Jocelyn Potter \n6 Advanced (3000 words) \n5 Upper Intermediate (2300 words) \n4 Intermediate (1700 words) \n3 Pre-lntermediate (1200 words) \n2 Elementary (600 words) \nI Beginner (300 words) \nEasystarts (200 words) Contemporary \nClassics \nOriginals \nBritish English \nAmerican English \nCover illustration Richard Jones \nLONGMAN \nPublished and distributed by \nAddison Wesley Longman\nDonna sees Mark on the boat to Spain. She likes him \nand he likes her. Then Mark sees Donna dancing with \nhis brother, Dave ... Is Donna in love with Mark? \nWhy is Dave dancing with her? \nPenguin Readers are simplified texts designed in association with \nLongman, the world famous educational publisher, to provide a step-by-\nstep approach to the joys of reading for pleasure. The series includes \noriginal stories, contemporary titles based on today's best-selling media \nhits, and easily accessible versions of the literary classics published by \nPenguin around the world. Each book has an introduction and extensive \nactivity material. They are published at seven levels from Easystarts (200 \nwords) to Advanced (3000 words). \nSeries Editors: Andy Hopkins and Jocelyn Potter \n6 Advanced (3000 words) \n5 Upper Intermediate (2300 words) \n4 Intermediate (1700 words) \n3 Pre-lntermediate (1200 words) \n2 Elementary (600 words) \nI Beginner (300 words) \nEasystarts (200 words) Contemporary \nClassics \nOriginals \nBritish English \nAmerican English \nCover illustration Richard Jones \nLONGMAN \nPublished and distributed by \nAddison Wesley Longman\nMark didn't want to go. He didn't want to eat or \ndance or talk and laugh. He wanted to sit quietly and \nthink about the good-looking girl on the boat. Where \nwas she now? But Dave and Harry and Nick and Sue \nall wanted him to go . . . \nLater that evening he walked into the square at \nComillas with his friends. They found a table at one of \nthe cafes and they all sat down. \n28\nMark didn't want to go. He didn't want to eat or \ndance or talk and laugh. He wanted to sit quietly and \nthink about the good-looking girl on the boat. Where \nwas she now? But Dave and Harry and Nick and Sue \nall wanted him to go . . . \nLater that evening he walked into the square at \nComillas with his friends. They found a table at one of \nthe cafes and they all sat down. \n28\nGirl Meets Boy \nDEREK STRANGE \nLevel 1 \nSeries Editors: Andy Hopkins and Jocelyn Potter\nGirl Meets Boy \nDEREK STRANGE \nLevel 1 \nSeries Editors: Andy Hopkins and Jocelyn Potter\nExercises \nVocabulary Work \nLook again at the 'Dictionary Words' in this story. Are they nouns \nor verbs or adjectives? Write the words and write N (for noun), V \n(for verb) or A (for adjective), e.g. story (N), bird (N). \nThen write short sentences with the new words. \nComprehension \nAnswer the questions. \nDonna's story \n1 (page 5) When was the first day of Donna's holiday? \n2 (page 6) Where was she when she first saw Mark? \n3 (page 9) How long were Donna and Mark on the boat together? \n4 (page 12) Who was on the dance-floor with Donna when she \nsaw Mark at the door of the disco? \n5 (page 15) At what time did the boat arrive in Santander? \nMark's story \n6 (page 16) What is Ma ...

# %%
template = f"""
Given the following extracted parts of a long document ("SOURCES") and a question ("QUESTION").
Don't try to make up an answer and use the text in the SOURCES only for the answer.
If you don't know the answer, just say that you don't know.
List down all the SOURCES in the response.

QUESTION: {query}
=========
SOURCES:
{verses}
=========
ANSWER:
"""

# %%
# Function to trim tokens in a string.
def trim_string_by_tokens(input_string, num_tokens):
    # Split the string into tokens
    tokens = input_string.split()

    # Ensure the number of tokens to keep is not greater than the total number of tokens
    num_tokens = min(num_tokens, len(tokens))

    # Join the desired number of tokens back together
    trimmed_string = ' '.join(tokens[:num_tokens])

    return trimmed_string.replace("/", " ")

# %%
final_prompt = (template, 1500)[0]
final_prompt
# Out:
# '\nGiven the following extracted parts of a long document ("SOURCES") and a question ("QUESTION").\nDon\'t try to make up an answer and use the text in the SOURCES only for the answer. \nIf you don\'t know the answer, just say that you don\'t know.\nList down all the SOURCES in the response.\n\nQUESTION: Who is the author of the book and what is his connection to the character Mark?\n=========\nSOURCES:\nDonna sees Mark on the boat to Spain. She likes him \nand he likes her. Then Mark sees Donna dancing with \nhis brother, Dave ... Is Donna in love with Mark? \nWhy is Dave dancing with her? \nPenguin Readers are simplified texts designed in association with \nLongman, the world famous educational publisher, to provide a step-by-\nstep approach to the joys of reading for pleasure. The series includes \noriginal stories, contemporary titles based on today\'s best-selling media \nhits, and easily accessible versions of the literary classics published by \nPenguin around the world. Each book has an introduction and extensive \nactivity material. They are published at seven levels from Easystarts (200 \nwords) to Advanced (3000 words). \nSeries Editors: Andy Hopkins and Jocelyn Potter \n6 Advanced (3000 words) \n5 Upper Intermediate (2300 words) \n4 Intermediate (1700 words) \n3 Pre-lntermediate (1200 words) \n2 Elementary (600 words) \nI Beginner (300 words) \nEasystarts (200 words) Contemporary \nClassics \nOriginals \nBritish English \nAmerican English \nCover illustration Richard Jones \nLONGMAN \nPublished and distributed by \nAddison Wesley Longman\nDonna sees Mark on the boat to Spain. She likes him \nand he likes her. Then Mark sees Donna dancing with \nhis brother, Dave ... Is Donna in love with Mark? \nWhy is Dave dancing with her? \nPenguin Readers are simplified texts designed in association with \nLongman, the world famous educational publisher, to provide a step-by-\nstep approach to the joys of reading for pleasure. The series includes \noriginal stories, contemporary titles based on today\'s best-selling media \nhits, and easily accessible versions of the literary classics published by \nPenguin around the world. Each book has an introduction and extensive \nactivity material. They are published at seven levels from Easystarts (200 \nwords) to Advanced (3000 words). \nSeries Editors: Andy Hopkins and Jocelyn Potter \n6 Advanced (3000 words) \n5 Upper Intermediate (2300 words) \n4 Intermediate (1700 words) \n3 Pre-lntermediate (1200 words) \n2 Elementary (600 words) \nI Beginner (300 words) \nEasystarts (200 words) Contemporary \nClassics \nOriginals \nBritish English \nAmerican English \nCover illustration Richard Jones \nLONGMAN \nPublished and distributed by \nAddison Wesley Longman\nMark didn\'t want to go. He didn\'t want to eat or \ndance or talk and laugh. He wanted to sit quietly and \nthink about the good-looking girl on the boat. Where \nwas she now? But Dave and Harry and Nick and Sue \nall wanted him to go . . . \nLater that evening he walked into the square at \nComillas with his friends. They found a table at one of \nthe cafes and they all sat down. \n28\nMark didn\'t want to go. He didn\'t want to eat or \ndance or talk and laugh. He wanted to sit quietly and \nthink about the good-looking girl on the boat. Where \nwas she now? But Dave and Harry and Nick and Sue \nall wanted him to go . . . \nLater that evening he walked into the square at \nComillas with his friends. They found a table at one of \nthe cafes and they all sat down. \n28\nGirl Meets Boy \nDEREK STRANGE \nLevel 1 \nSeries Editors: Andy Hopkins and Jocelyn Potter\nGirl Meets Boy \nDEREK STRANGE \nLevel 1 \nSeries Editors: Andy Hopkins and Jocelyn Potter\nExercises \nVocabulary Work \nLook again at the \'Dictionary Words\' in this story. Are they nouns \nor verbs or adjectives? Write the words and write N (for noun), V \n(for verb) or A (for adjective), e.g. story (N), bird (N). \nThen write short sentences with the new words. \nComprehen ...

# %%
prompt1_response_mistral = llm_mistral(final_prompt)

# %%
prompt1_response_mistral
# Out:
# 'The author of the book "Girl Meets Boy" is Derek Strange. Mark is a character in the book, but there is no explicit information provided in the sources about the connection between the author and the character Mark.\n\nSOURCES:\n- The text mentions that Donna sees Mark on the boat to Spain and they both like each other. It also describes Mark\'s reluctance to go out with his friends and his thoughts about Donna.\n- The sources include information about the Penguin Readers series, which includes "Girl Meets Boy" by Derek Strange at Level 1. The series editors are Andy Hopkins and Jocelyn Potter, and the books are published in various levels from Beginner to Advanced. The cover illustration is by Richard Jones, and Longman publishes and distributes the books.\n- The sources also include exercises for vocabulary work, comprehension questions related to Donna\'s story, Mark\'s story, and the town\'s story, as well as discussion questions.'

# %%
print(prompt1_response_mistral.split("\n\nSOURCES:")[0])
# Out:
# The author of the book "Girl Meets Boy" is Derek Strange. Mark is a character in the book, but there is no explicit information provided in the sources about the connection between the author and the character Mark.

# %%
print(prompt1_response_mistral.split("\n\nSOURCES:")[1])
# Out:
# - The text mentions that Donna sees Mark on the boat to Spain and they both like each other. It also describes Mark's reluctance to go out with his friends and his thoughts about Donna.
# - The sources include information about the Penguin Readers series, which includes "Girl Meets Boy" by Derek Strange at Level 1. The series editors are Andy Hopkins and Jocelyn Potter, and the books are published in various levels from Beginner to Advanced. The cover illustration is by Richard Jones, and Longman publishes and distributes the books.
# - The sources also include exercises for vocabulary work, comprehension questions related to Donna's story, Mark's story, and the town's story, as well as discussion questions.
